# %%
#1 Load data

import pandas as pd

# Load the CSV file into a DataFrame
data = pd.read_csv(r"C:\Data Manipulation Technique/Top2000CompaniesGlobally.csv")

# Display the first few rows of the DataFrame to inspect its contents
data.head()
# Out:
#    Global Rank                  Company  Sales ($billion)  Profits ($billion)  \
# 0            1                     ICBC             134.8                37.8
# 1            2  China Construction Bank             113.1                30.6
# 2            3           JPMorgan Chase             108.2                21.3
# 3            4         General Electric             147.4                13.6
# 4            5              Exxon Mobil             420.7                44.9
#
#    Assets ($billion)  Market Value ($billion) Country      Continent  \
# 0             2813.5                    237.3   China           Asia
# 1             2241.0                    202.0   China           Asia
# 2             2359.1                    191.4     USA  North America
# 3              685.3                    243.7     USA  North America
# 4              333.8                    400.4     USA  North America
#
#    Latitude   Longitude
# 0  35.86166  104.195397
# 1  35.86166  104.195397
# ...

# %%
#2 Check for missing values

# Check for missing values in the dataset
missing_values = data.isnull().sum()

missing_values
# Out:
# Global Rank                0
# Company                    0
# Sales ($billion)           0
# Profits ($billion)         0
# Assets ($billion)          0
# Market Value ($billion)    0
# Country                    0
# Continent                  0
# Latitude                   0
# Longitude                  0
# dtype: int64

# %%
#3 Check for duplicate rows

# Check for duplicate rows in the dataset
duplicate_rows = data.duplicated().sum()

duplicate_rows
# Out:
# 0

# %%
#4 Check for potential outliers or incorrect values

# Display statistical summary for the numerical columns
numerical_summary = data.describe()

numerical_summary
# Out:
#        Global Rank  Sales ($billion)  Profits ($billion)  Assets ($billion)  \
# count  1924.000000       1924.000000         1924.000000        1924.000000
# mean    997.232848         19.265904            1.226040          79.507796
# std     575.502781         34.683911            3.413831         261.098775
# min       1.000000          0.000000          -24.500000           1.000000
# 25%     500.750000          4.100000            0.300000           9.675000
# 50%     997.500000          9.000000            0.600000          19.250000
# 75%    1494.250000         18.425000            1.200000          45.800000
# max    1999.000000        469.200000           44.900000        3226.200000
#
#        Market Value ($billion)     Latitude    Longitude
# count              1924.000000  1924.000000  1924.000000
# mean                 19.558160    34.618747    15.455664
# std                  32.957023    18.259499    92.639655
# ...

# %%
#5 Inspect unique values

# Check unique values in the categorical columns
unique_country = data['Country'].unique()
unique_continent = data['Continent'].unique()

unique_country, unique_continent
# Out:
# (array(['China', 'USA', 'UK', 'The Netherlands', 'Germany', 'Russia',
#         'Brazil', 'South Korea', 'France', 'Japan', 'Hong Kong', 'Italy',
#         'Norway', 'Australia', 'Spain', 'Canada', 'Belgium',
#         'Saudi Arabia', 'Mexico', 'Taiwan', 'Colombia', 'Sweden', 'India',
#         'Denmark', 'Thailand', 'South Africa', 'Israel', 'Singapore',
#         'Turkey', 'Ireland', 'Malaysia', 'Panama', 'Portugal',
#         'Czech Republic', 'Finland', 'Indonesia', 'Luxembourg',
#         'United Arab Emirates', 'Qatar', 'Chile', 'Poland', 'Hungary',
#         'Kuwait', 'Philippines', 'Bermuda', 'Peru', 'Morocco',
#         'Kazakhstan', 'Greece', 'Venezuela', 'Nigeria', 'Egypt', 'Liberia',
#         'Jordan', 'Pakistan', 'Lebanon', 'Oman', 'Channel Islands',
#         'Vietnam', 'New Zealand'], dtype=object),
#  array(['Asia', 'North America', 'Europe', 'South America', 'Oceania',
#         'Africa'], dtype=object))
